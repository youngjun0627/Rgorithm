# %%
def solution(info, query):
    answer = [0 for _ in range(len(query))]
    info_list = []
    query_list = []
    for i in info:
        temp = i.split(' ')
        info_list.append(temp)
    for q in query:   
        temp = q.split(' ')
        while True:
            if 'and' in temp:
                temp.remove('and')
            else:
                break
        query_list.append(temp)
    
    dic = {}
    dic['java'] = {'frontend':{'junior':{'chicken':[], 'pizza':[]},
                               'senior':{'chicken':[], 'pizza':[]}},
                    'backend':{'junior':{'chicken':[], 'pizza':[]},
                               'senior':{'chicken':[], 'pizza':[]}}}
    dic['python'] = {'frontend':{'junior':{'chicken':[], 'pizza':[]},
                               'senior':{'chicken':[], 'pizza':[]}},
                    'backend':{'junior':{'chicken':[], 'pizza':[]},
                               'senior':{'chicken':[], 'pizza':[]}}}
    dic['cpp'] = {'frontend':{'junior':{'chicken':[], 'pizza':[]},
                               'senior':{'chicken':[], 'pizza':[]}},
                    'backend':{'junior':{'chicken':[], 'pizza':[]},
                               'senior':{'chicken':[], 'pizza':[]}}}
    for infos in info_list:
        if infos[0]=='java':
            if infos[1]=='frontend':
                if infos[2]=='junior':
                    if infos[3] == 'chicken':
                        dic['java']['frontend']['junior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        dic['java']['frontend']['junior']['pizza'].append(int(infos[4]))
                elif infos[2]=='senior':
                    if infos[3] == 'chicken':
                        dic['java']['frontend']['senior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        dic['java']['frontend']['senior']['pizza'].append(int(infos[4]))
            elif infos[1]=='backend':
                if infos[2]=='junior':
                    if infos[3] == 'chicken':
                        dic['java']['backend']['junior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        dic['java']['backend']['junior']['pizza'].append(int(infos[4]))
                elif infos[2]=='senior':
                    if infos[3] == 'chicken':
                        dic['java']['backend']['senior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        dic['java']['backend']['senior']['pizza'].append(int(infos[4]))
        elif infos[0]=='python':
            if infos[1]=='frontend':
                if infos[2]=='junior':
                    if infos[3] == 'chicken':
                        dic['python']['frontend']['junior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        dic['python']['frontend']['junior']['pizza'].append(int(infos[4]))
                elif infos[2]=='senior':
                    if infos[3] == 'chicken':
                        dic['python']['frontend']['senior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        dic['python']['frontend']['senior']['pizza'].append(int(infos[4]))
            elif infos[1]=='backend':
                if infos[2]=='junior':
                    if infos[3] == 'chicken':
                        dic['python']['backend']['junior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        dic['python']['backend']['junior']['pizza'].append(int(infos[4]))
                elif infos[2]=='senior':
                    if infos[3] == 'chicken':
                        dic['python']['backend']['senior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        dic['python']['backend']['senior']['pizza'].append(int(infos[4]))
                    
                
        elif infos[0]=='cpp':
            if infos[1]=='frontend':
                if infos[2]=='junior':
                    if infos[3] == 'chicken':
                        dic['cpp']['frontend']['junior']['chicken'].append(int(infos[4])) 
                    elif infos[3] == 'pizza':
                        dic['cpp']['frontend']['junior']['pizza'].append(int(infos[4]))
                elif infos[2]=='senior':
                    if infos[3] == 'chicken':
                        dic['cpp']['frontend']['senior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        dic['cpp']['frontend']['senior']['pizza'].append(int(infos[4]))
            elif infos[1]=='backend':
                if infos[2]=='junior':
                    if infos[3] == 'chicken':
                        dic['cpp']['backend']['junior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        dic['cpp']['backend']['junior']['pizza'].append(int(infos[4]))
                elif infos[2]=='senior':
                    if infos[3] == 'chicken':
                        dic['cpp']['backend']['senior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        dic['cpp']['backend']['senior']['pizza'].append(int(infos[4]))
                    
    #print(dic)
    #print('-------------------------------')
    #print(info_list.sort())
    index=0
    
    for querys in query_list:
        lang,job,skill,food,score = querys
        score = int(score)
        lang_list=[]
        job_list=[]
        skill_list=[]
        food_list=[]
        cnt=0
        #print(lang,job,skill,food,score)
        if lang=='-':
            lang_list = ['java','python','cpp']
        else:
            lang_list.append(lang)
            
        if job=='-':
            job_list = ['frontend','backend']
        else:
            job_list.append(job)
                        
        if skill=='-':
            skill_list = ['junior','senior']
        else:
            skill_list.append(skill)
                        
        if food=='-':
            food_list = ['chicken','pizza']
        else:
            food_list.append(food)

        for langs in lang_list:
            for jobs in job_list:
                for skills in skill_list:
                    for foods in food_list:
                        for i in dic[langs][jobs][skills][foods]:
                            if i >= score:
                                cnt+=1
                                #print(langs,jobs,skills,foods,score,i)
        answer[index]=cnt
        index+=1
    #print(arr)
        
        
        #print(check_lang,check_job,check_skill,check_food,check_score)
    #print(lang, job, skill, food, score)
    #print(check_lang,check_job,check_skill,check_food,check_score)
    return answer
#info = ["java backend junior pizza 150","python frontend senior chicken 210","python frontend senior chicken 150","cpp backend senior pizza 260","java backend junior chicken 80","python backend senior chicken 50"]
#query = ["java and backend and junior and pizza 100","python and frontend and senior and chicken 200","cpp and - and senior and pizza 250","- and backend and senior and - 150","- and - and - and chicken 100","- and - and - and - 150"]
#solution(info,query)

# %%
def solution(info, query):
    answer = [0 for _ in range(len(query))]
    info_list = []
    query_list = []
    for i in info:
        temp = i.split(' ')
        info_list.append(temp)
    for q in query:   
        temp = q.split(' ')
        while True:
            if 'and' in temp:
                temp.remove('and')
            else:
                break
        query_list.append(temp)
    
    dic = {}
    dic['java'] = {'frontend':{'junior':{'chicken':[], 'pizza':[]},
                               'senior':{'chicken':[], 'pizza':[]}},
                    'backend':{'junior':{'chicken':[], 'pizza':[]},
                               'senior':{'chicken':[], 'pizza':[]}}}
    dic['python'] = {'frontend':{'junior':{'chicken':[], 'pizza':[]},
                               'senior':{'chicken':[], 'pizza':[]}},
                    'backend':{'junior':{'chicken':[], 'pizza':[]},
                               'senior':{'chicken':[], 'pizza':[]}}}
    dic['cpp'] = {'frontend':{'junior':{'chicken':[], 'pizza':[]},
                               'senior':{'chicken':[], 'pizza':[]}},
                    'backend':{'junior':{'chicken':[], 'pizza':[]},
                               'senior':{'chicken':[], 'pizza':[]}}}
    for infos in info_list:
        if infos[0]=='java':
            if infos[0] not in dic:
                dic['java'] = {}
            if infos[1]=='frontend':
                if infos[1] not in dic['java']:
                    dic['java']['frontend'] = {}
                if infos[2]=='junior':
                    if infos[2] not in dic['java']['frontend']:
                        dic['java']['frontend']['junior'] = {}
                    if infos[3] == 'chicken':
                        if infos[3] not in dic['java']['frontend']['junior']:
                            dic['java']['frontend']['junior']['chicken'] = []
                        dic['java']['frontend']['junior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        if infos[3] not in dic['java']['frontend']['junior']:
                            dic['java']['frontend']['junior']['pizza'] = []
                        dic['java']['frontend']['junior']['pizza'].append(int(infos[4]))
                elif infos[2]=='senior':
                    if infos[2] not in dic['java']['frontend']:
                        dic['java']['frontend']['senior'] = {}
                    if infos[3] == 'chicken':
                        if infos[3] not in dic['java']['frontend']['senior']:
                            dic['java']['frontend']['senior']['chicken'] = []
                        dic['java']['frontend']['senior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        if infos[3] not in dic['java']['frontend']['senior']:
                            dic['java']['frontend']['senior']['pizza'] = []
                        dic['java']['frontend']['senior']['pizza'].append(int(infos[4]))
            elif infos[1]=='backend':
                if infos[1] not in dic['java']:
                    dic['java']['backend'] = {}
                if infos[2]=='junior':
                    if infos[2] not in dic['java']['frontend']:
                        dic['java']['backend']['junior'] = {}
                    if infos[3] == 'chicken':
                        if infos[3] not in dic['java']['backend']['junior']:
                            dic['java']['backend']['junior']['chicken'] = []
                        dic['java']['backend']['junior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        if infos[3] not in dic['java']['backend']['junior']:
                            dic['java']['backend']['junior']['pizza'] = []
                        dic['java']['backend']['junior']['pizza'].append(int(infos[4]))
                elif infos[2]=='senior':
                    if infos[2] not in dic['java']['backend']:
                        dic['java']['backend']['senior'] = {}
                    if infos[3] == 'chicken':
                        if infos[3] not in dic['java']['backend']['senior']:
                            dic['java']['backend']['senior']['chicken'] = []
                        dic['java']['backend']['senior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        if infos[3] not in dic['java']['backend']['senior']:
                            dic['java']['backend']['senior']['pizza'] = []
                        dic['java']['backend']['senior']['pizza'].append(int(infos[4]))
        elif infos[0]=='python':
            if infos[0] not in dic:
                dic['python'] = {}
            if infos[1]=='frontend':
                if infos[1] not in dic['python']:
                    dic['python']['frontend'] = {}
                if infos[2]=='junior':
                    if infos[2] not in dic['python']['frontend']:
                        dic['python']['frontend']['junior'] = {}
                    if infos[3] == 'chicken':
                        if infos[3] not in dic['python']['frontend']['junior']:
                            dic['python']['frontend']['junior']['chicken'] = []
                        dic['python']['frontend']['junior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        if infos[3] not in dic['python']['frontend']['junior']:
                            dic['python']['frontend']['junior']['pizza'] = []
                        dic['python']['frontend']['junior']['pizza'].append(int(infos[4]))
                elif infos[2]=='senior':
                    if infos[2] not in dic['python']['frontend']:
                        dic['python']['frontend']['senior'] = {}
                    if infos[3] == 'chicken':
                        if infos[3] not in dic['python']['frontend']['senior']:
                            dic['python']['frontend']['senior']['chicken'] = []
                        dic['python']['frontend']['senior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        if infos[3] not in dic['python']['frontend']['senior']:
                            dic['python']['frontend']['senior']['pizza'] = []
                        dic['python']['frontend']['senior']['pizza'].append(int(infos[4]))
            elif infos[1]=='backend':
                if infos[1] not in dic['python']:
                    dic['python']['backend'] = {}
                if infos[2]=='junior':
                    if infos[2] not in dic['python']['frontend']:
                        dic['python']['backend']['junior'] = {}
                    if infos[3] == 'chicken':
                        if infos[3] not in dic['python']['backend']['junior']:
                            dic['python']['backend']['junior']['chicken'] = []
                        dic['python']['backend']['junior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        if infos[3] not in dic['python']['backend']['junior']:
                            dic['python']['backend']['junior']['pizza'] = []
                        dic['python']['backend']['junior']['pizza'].append(int(infos[4]))
                elif infos[2]=='senior':
                    if infos[2] not in dic['python']['backend']:
                        dic['python']['backend']['senior'] = {}
                    if infos[3] == 'chicken':
                        if infos[3] not in dic['python']['backend']['senior']:
                            dic['python']['backend']['senior']['chicken'] = []
                        dic['python']['backend']['senior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        if infos[3] not in dic['python']['backend']['senior']:
                            dic['python']['backend']['senior']['pizza'] = []
                        dic['python']['backend']['senior']['pizza'].append(int(infos[4]))
                
        elif infos[0]=='cpp':
            if infos[0] not in dic:
                dic['cpp'] = {}
            if infos[1]=='frontend':
                if infos[1] not in dic['cpp']:
                    dic['cpp']['frontend'] = {}
                if infos[2]=='junior':
                    if infos[2] not in dic['cpp']['frontend']:
                        dic['cpp']['frontend']['junior'] = {}
                    if infos[3] == 'chicken':
                        if infos[3] not in dic['cpp']['frontend']['junior']:
                            dic['cpp']['frontend']['junior']['chicken'] = []
                        dic['cpp']['frontend']['junior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        if infos[3] not in dic['cpp']['frontend']['junior']:
                            dic['cpp']['frontend']['junior']['pizza'] = []
                        dic['cpp']['frontend']['junior']['pizza'].append(int(infos[4]))
                elif infos[2]=='senior':
                    if infos[2] not in dic['cpp']['frontend']:
                        dic['cpp']['frontend']['senior'] = {}
                    if infos[3] == 'chicken':
                        if infos[3] not in dic['cpp']['frontend']['senior']:
                            dic['cpp']['frontend']['senior']['chicken'] = []
                        dic['cpp']['frontend']['senior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        if infos[3] not in dic['cpp']['frontend']['senior']:
                            dic['cpp']['frontend']['senior']['pizza'] = []
                        dic['cpp']['frontend']['senior']['pizza'].append(int(infos[4]))
            elif infos[1]=='backend':
                if infos[1] not in dic['cpp']:
                    dic['cpp']['backend'] = {}
                if infos[2]=='junior':
                    if infos[2] not in dic['cpp']['frontend']:
                        dic['cpp']['backend']['junior'] = {}
                    if infos[3] == 'chicken':
                        if infos[3] not in dic['cpp']['backend']['junior']:
                            dic['cpp']['backend']['junior']['chicken'] = []
                        dic['cpp']['backend']['junior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        if infos[3] not in dic['cpp']['backend']['junior']:
                            dic['cpp']['backend']['junior']['pizza'] = []
                        dic['cpp']['backend']['junior']['pizza'].append(int(infos[4]))
                elif infos[2]=='senior':
                    if infos[2] not in dic['cpp']['backend']:
                        dic['cpp']['backend']['senior'] = {}
                    if infos[3] == 'chicken':
                        if infos[3] not in dic['cpp']['backend']['senior']:
                            dic['cpp']['backend']['senior']['chicken'] = []
                        dic['cpp']['backend']['senior']['chicken'].append(int(infos[4]))
                    elif infos[3] == 'pizza':
                        if infos[3] not in dic['cpp']['backend']['senior']:
                            dic['cpp']['backend']['senior']['pizza'] = []
                        dic['cpp']['backend']['senior']['pizza'].append(int(infos[4]))
                    
    print(dic)
    #print('-------------------------------')
    #print(info_list.sort())
    index=0
    
    for querys in query_list:
        lang,job,skill,food,score = querys
        score = int(score)
        lang_list=[]
        job_list=[]
        skill_list=[]
        food_list=[]
        cnt=0
        #print(lang,job,skill,food,score)
        if lang=='-':
            lang_list = ['java','python','cpp']
        else:
            lang_list.append(lang)
            
        if job=='-':
            job_list = ['frontend','backend']
        else:
            job_list.append(job)
                        
        if skill=='-':
            skill_list = ['junior','senior']
        else:
            skill_list.append(skill)
                        
        if food=='-':
            food_list = ['chicken','pizza']
        else:
            food_list.append(food)

        for langs in lang_list:
            if langs in dic:
                for jobs in job_list:
                    if jobs in dic[langs]:
                        for skills in skill_list:
                            if skills in dic[langs][jobs]:
                                for foods in food_list:
                                    if foods in dic[langs][jobs][skills]:
                                        for i in dic[langs][jobs][skills][foods]:
                                            if i >= score:
                                                cnt+=1
                                    #print(langs,jobs,skills,foods,score,i)
        answer[index]=cnt
        index+=1
    #print(arr)
        
        
        #print(check_lang,check_job,check_skill,check_food,check_score)
    #print(lang, job, skill, food, score)
    #print(check_lang,check_job,check_skill,check_food,check_score)
    return answer
info = ["java backend junior pizza 150","python frontend senior chicken 210","python frontend senior chicken 150","cpp backend senior pizza 260","java backend junior chicken 80","python backend senior chicken 50"]
query = ["java and backend and junior and pizza 100","python and frontend and senior and chicken 200","cpp and - and senior and pizza 250","- and backend and senior and - 150","- and - and - and chicken 100","- and - and - and - 150"]
solution(info,query)
# Out:
# {'java': {'frontend': {'junior': {'chicken': [], 'pizza': []}, 'senior': {'chicken': [], 'pizza': []}}, 'backend': {'junior': {'chicken': [80], 'pizza': [150]}, 'senior': {'chicken': [], 'pizza': []}}}, 'python': {'frontend': {'junior': {'chicken': [], 'pizza': []}, 'senior': {'chicken': [210, 150], 'pizza': []}}, 'backend': {'junior': {'chicken': [], 'pizza': []}, 'senior': {'chicken': [50], 'pizza': []}}}, 'cpp': {'frontend': {'junior': {'chicken': [], 'pizza': []}, 'senior': {'chicken': [], 'pizza': []}}, 'backend': {'junior': {'chicken': [], 'pizza': []}, 'senior': {'chicken': [], 'pizza': [260]}}}}
# [1, 1, 1, 1, 2, 4]
